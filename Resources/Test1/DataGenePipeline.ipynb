# %%
import PyPDF2

with open('/Users/Nian/Desktop/School/BusinessSchool_RA/LLMs/Datasets/PDFs/document.pdf', 'rb') as pdf_file:
    reader = PyPDF2.PdfReader(pdf_file)
    text = ''

    for i in range(len(reader.pages)):
        page = reader.pages[i]
        text += page.extract_text()

print(text)
# Out:
# MANUFACTURING & SERVICE
# OPERATIONS MANAGEMENTVol. 14, No. 1, Winter 2012, pp. 145–162
# ISSN 1523-4614 (print) ISSN 1526-5498 (online)
# http://dx.doi.org/10.1287/msom.1110.0356
# © 2012 INFORMS
# Effect of Trafﬁc on Sales and
# Conversion Rates of Retail Stores
# Olga Perdikaki
# Mays Business School, Texas A&M University, College Station, Texas 77843,
# operdikaki@tamu.edu
# Saravanan Kesavan, Jayashankar M. Swaminathan
# Kenan-Flagler Business School, University of North Carolina, Chapel Hill, North Carolina 27599
# {skesavan@unc.edu, msj@unc.edu}
# Attracting shoppers to stores and converting the incoming trafﬁc into sales proﬁtably are vital for the ﬁnancial
# health of retailers. In this paper, we use proprietary data pertaining to an apparel retailer to study the
# relationship between store trafﬁc, labor, and sales performance. We decompose sales volume into conversion
# ...

# %%
# max char 2048
import openai
import os
import pandas as pd
import time

openai.api_key = ''

def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
    model=model,
    messages=messages,
    temperature=0,
    )
    return response.choices[0].message["content"]

# %%
prompt = '''I am fine tuning a LLM. Right now, I have text. And I want you to extract question-answer pair from them. Since I will upload other files. Please insure data quality for fine tuning LLM.    Please make sure you found all the question-answer pairs. Please make sure the generated format is in Json format like: [
  {
    "question": ,
    "answer": 
  },
  {
    "question": ,
    "answer": 
  },...'''
text = '''4. Methodology and Estimation  
In this section we explain the methodology used to determine if retail stores are under or overstaffed. 
We determine a store to be understaffed in a given time  period if it carries less than optimal labor in that 
time period. In order to determine the optimal labor, we extract the revenue function and cost function for 
each store. To do so, we assume that store managers make optimal labor decisions at an aggregate daily 
level and derive the revenue and cost  functions for each store using historical daily data on sales, traffic, 
and labor. We justify this assumption based on the in centive structure of store managers whose bonuses 
are tied to store profits. Using the parameter estimat es, we derive the optimal labor for each individual 
hour. The difference in actual labor and optimal labor is used to identify understaffing and overstaffing 
periods in the dataset.  
In order to estimate the revenue function and cost  function for each store, we make the following 
assumptions. First, we assume that the revenue fu nction only depends upon the incoming traffic and 
amount of labor in the store. Second, we assume consta nt marginal cost of labor in our cost function. The 
manager knows this marginal cost when making staffi ng decisions but this cost is unobservable to the 
econometrician. We allow for marginal cost to vary  across stores for the following reasons. First, some 
components of the accounting costs such as minimum wa ge rate, insurance, and medical benefits could 
vary across stores based on state laws in the United St ates. Thus stores within the same chain would be 
paying different wages for similar jobs. Second, the cost of labor could be driven by local market 
characteristics such as labor supply and customer exp ectations. Local markets with tight labor supply 
might face high employee turnover. High employee turnover increases labor costs due to increase in costs 
of hiring and training (Stiglitz 1974) and additional overtime costs till the vacancy is filled (Tziner and 10 
 Birati 1996). Similarly, managers of stores that are lo cated in markets where customers’ expectation of 
service is higher might place greater emphasis on service level and assess lower costs to labor. For example, Campbell and Frei (2010) find that operating managers in a retail bank consider market-specific 
customer sensitivity to service time when they trade-o ff cost versus benefit of service to be provided.  
Finally, the cost of labor could depend upon the efficiency of labor and management in each store 
(Thomadsen 2005).  
We use a structural estimation technique to determine the revenue and cost function for each store. 
Structural estimation techniques are useful to estimat e unobservable or behavioral parameters (Reiss and 
Wolak 2007). A key decision in structural estimation is  the choice of the underlying model that is used to 
capture managers’ decision making process. Reiss and Wo lak (2007) state that the choice of the structural 
model depends upon economic reality, data generating process, and ability to simplify estimation. We are 
guided by similar principles in our choice of the stru ctural model. This retailer has a centrally planned 
tool that provides guidelines to the store managers, who then make the labor planning decisions. Prior 
empirical evidence on store manager incentives suggest that retailers develop incentive schemes for store 
managers with a goal of maximizing store prof its (Dehoratius and Raman, 2007). In case of Alpha , store 
managers received an incentive compensation based on store profits. Hence, we argue that the store 
managers’ labor decisions are taken w ith the goal of maximizing store profits'''

combined_text = prompt + text

response = get_completion(combined_text)
print(response)
# Out:
# [
#   {
#     "question": "What was the purpose of Beta contacting the author?",
#     "answer": "Beta was contemplating purchase of labor planning software to improve their staffing decisions and contacted us to identify any understaffing in their stores."
#   },
#   {
#     "question": "What were the similarities between the store managers of Alpha and Beta?",
#     "answer": "In both cases, store managers were responsible for making labor decisions and the store managers’ compensation was based on salary as well as bonuses that were tied to store profits. Customer satisfaction metrics were not considered in the performance appraisal of store managers."
#   },
#   {
#     "question": "What approach did the author follow for model validation and analysis?",
# ...

# %%
# training data generation pipeline
import PyPDF2
import openai
import json
import re
import time

start_time = time.time()  

with open('/Users/Nian/Desktop/School/BusinessSchool_RA/LLMs/Datasets/PDFs/10.1.1.1049.6903.pdf', 'rb') as pdf_file:
    reader = PyPDF2.PdfReader(pdf_file)
    text = ''

    for i in range(len(reader.pages)):
        page = reader.pages[i]
        text += page.extract_text()

openai.api_key = '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'

def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message["content"]

prompt = '''I am fine tuning a LLM. Right now, I have text. And I want you to extract question-answer pair from them. Since I will upload other files. Please insure data quality for fine tuning LLM. Please make sure you found all the question-answer pairs. Please make sure the generated format is in Json format like: [
  {
    "question": ,
    "answer": 
  },
  {
    "question": ,
    "answer": 
  },...'''

qa_pairs = []

tokens_per_chunk = 2048
for i in range(0, len(text), tokens_per_chunk):
    chunk = text[i:i+tokens_per_chunk]
    combined_text = prompt + chunk
    response = get_completion(combined_text)

    qa_match = re.findall(r"\{[^\}]*\"question\": [^\}]*\}", response)

    for match in qa_match:
        try:
            qa_pairs.append(json.loads(match))
        except json.JSONDecodeError:
            print(f"Failed to parse response to JSON: {match}")

with open('qa_pairs.json', 'w') as json_file:
    json.dump(qa_pairs, json_file)

end_time = time.time()  
total_pages = len(reader.pages)  
average_time_per_page = (end_time - start_time) / total_pages  

print(f"Average time per page: {average_time_per_page} seconds")
# Out:
# Failed to parse response to JSON: {
#     "question": "What does ܽௗ represent in equation (6)?",
#     "answer": "ܽௗ	ൌ1 if day of week ݀ = 1, 0 otherwise"
#   }
# Failed to parse response to JSON: {
#     "question": "What does ܽ௠ represent in equation (6)?",
#     "answer": "ܽ௠	ൌ1 if month of year ݉ = 1, 0 otherwise"
#   }
# Failed to parse response to JSON: {
#     "question": "What are the two moment conditions obtained after applying logarithmic transformation to equations 5 and 6?",
#     "answer": "ܧ൤ݖଵ௜௧	൜log	 ሺߛ ௜ߙ௜ߙ௜௠௔೘ߙ௜ௗ௔೏ܰ௜௧ఉ೔݁ିఊ೔௟೔೟ൗሻെlog	 ሺݓ ௜݈௜௧ଶሻൠ൨ൌ0 and ܧ൤ݖଶ௜௧	൜log	 ሺܵ ௜௧ሻെ	log	 ሺߙ ௜ߙ௜௠௔೘"
#   }
# Failed to parse response to JSON: {
#     "question": "What is the average traffic elasticity ( ߚ௜	) for each of the 41 stores?",
#     "answer": "The average traffic elasticity ( ߚ௜	) for each of the 41 stores was found to be lower during weekends as compared to weekdays ( p<0.05)."
#   }
# Failed to parse response to JSON: {
# ...

# %%
qa_pairs
# Out:
# [{'question': 'What is the paper about?',
#   'answer': 'The paper is about estimating the impact of understaffing on sales and profitability in retail stores.'},
#  {'question': 'What data is used in the paper?',
#   'answer': 'Micro-level data on store traffic, sales, and labor from 41 stores of a large retail chain.'},
#  {'question': 'How is traffic data used in making staffing decisions?',
#   'answer': 'Traffic data is used to leverage a structural model that captures the relationship between traffic, sales, and labor.'},
#  {'question': 'What is the objective of store managers?',
#   'answer': 'Store managers aim to maximize profits.'},
#  {'question': 'What is the estimated contribution of labor to sales?',
#   'answer': 'The estimated contribution of labor to sales varies across stores and time.'},
#  {'question': 'What is the potential impact of aligning staffing levels with changing traffic patterns?',
# ...
